# %% [markdown]
# <h3> Segmenting and Clustering Neighborhoods in Toronto</h3>

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import io

# %% [markdown]
# WEB SCRAPING

# %%
wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
web_texto= requests.get(wikipedia_link).text


Canada_dado = BeautifulSoup(web_texto,'xml')

# %% [markdown]
# EXTRAINDO DADOS DA WEBPAGE

# %%
table = Canada_dado.find('table')

Postcode      = []
Borough       = []
Neighbourhood = []


for tr_cell in table.find_all('tr'):
    
    counter = 1
    Postcode_var      = -1
    Borough_var       = -1
    Neighbourhood_var = -1
    
    for td_cell in tr_cell.find_all('td'):
        if counter == 1: 
            Postcode_var = td_cell.text
        if counter == 2: 
            Borough_var = td_cell.text
            tag_a_Borough = td_cell.find('a')
            
        if counter == 3: 
            Neighbourhood_var = str(td_cell.text).strip()
            tag_a_Neighbourhood = td_cell.find('a')
            
        counter +=1
        
        if (Postcode_var == 'Not assigned' or Borough_var == 'Not assigned' or Neighbourhood_var == 'Not assigned'):
            
            continue
            
           
    try:
        if ((tag_a_Borough is None) or (tag_a_Neighbourhood is None)):
            
            continue
            
            
    except:
        
        pass
    
    if(Postcode_var == -1 or Borough_var == -1 or Neighbourhood_var == -1):
        
        continue
        
    Postcode.append(Postcode_var)
    Borough.append(Borough_var)
    Neighbourhood.append(Neighbourhood_var)

# %% [markdown]
# INTEGRANDO AS VIZINHANÇAS

# %%
unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []


for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
# Out:
# num of unique Postal codes: 77

# %% [markdown]
# CRIANDO O DATAFRAME

# %%
toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u}
df = pd.DataFrame.from_dict(toronto_dict)

df.head(14)
# Out:
#    Postcode           Borough  \
# 0       M4H         East York
# 1       M5E  Downtown Toronto
# 2       M5M        North York
# 3       M1S       Scarborough
# 4       M6K      West Toronto
# 5       M8Y         Etobicoke
# 6       M9M        North York
# 7       M3J        North York
# 8       M6S      West Toronto
# 9       M7A  Downtown Toronto
# 10      M8V         Etobicoke
# 11      M2M        North York
# 12      M1X       Scarborough
# 13      M1R       Scarborough
#
#                                         Neighbourhood
# 0                                    Thorncliffe Park
# 1                                         Berczy Park
# 2                                        Bedford Park
# 3                                           Agincourt
# 4                  Exhibition Place, Parkdale Village
# 5   Humber Bay, Mimico NE, Old Mill South, The Que...
# 6                                    Emery, Humberlea
# 7                     Northwood Park, York University
# 8                                  Runnymede, Swansea
# 9                                        Queen's Park
# 10                                        New Toronto
# 11                            Newtonbrook, Willowdale
# 12                                        Upper Rouge
# 13                                  Maryvale, Wexford

# %% [markdown]
# LATITUDE E LONGITUDE

# %%
url="http://cocl.us/Geospatial_data"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
c.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
c.columns = ['Postcode', 'Latitude', 'Longitude']

# %%
df_toronto = pd.merge(c, df, on='Postcode')

# %%
df_toronto = df_toronto[['Postcode', 'Borough', 'Neighbourhood', 'Latitude', 'Longitude']]

# %%
df_toronto
# Out:
#    Postcode           Borough  \
# 0       M1B       Scarborough
# 1       M1C       Scarborough
# 2       M1E       Scarborough
# 3       M1G       Scarborough
# 4       M1J       Scarborough
# 5       M1K       Scarborough
# 6       M1L       Scarborough
# 7       M1M       Scarborough
# 8       M1N       Scarborough
# 9       M1P       Scarborough
# 10      M1R       Scarborough
# 11      M1S       Scarborough
# 12      M1T       Scarborough
# 13      M1V       Scarborough
# 14      M1X       Scarborough
# 15      M2H        North York
# 16      M2J        North York
# 17      M2K        North York
# 18      M2L        North York
# 19      M2M        North York
# 20      M2R        North York
# 21      M3A        North York
# 22      M3C        North York
# 23      M3H        North York
# 24      M3J        North York
# 25      M3K        North York
# 26      M3L        North York
# 27      M4A        North York
# 28      M4B         East York
# 29      M4C         East York
# ..      ...               ...
# 47      M5L  Downtown Toronto
# 48      M5M        North York
# 49      M5P   Central Toronto
# 50      M5R   Central Toronto
# 51      M5S  Downtown Toronto
# 52      M5T  Downtown Toronto
# 53      M5V  Downtown Toronto
# 54      M5X  Downtown Toronto
# 55      M6A        North York
# 56      M6H      West Toronto
# 57      M6J      West Toronto
# 58      M6K      West Toronto
# 59      M6L        North York
# 60      M6M              York
# 61      M6P      West Toronto
# 62      M6R      West Toronto
# 63      M6S      West Toronto
# 64      M7A  Downtown Toronto
# 65      M8V         Etobicoke
# 66      M8W         Etobicoke
# 67      M8X         Etobicoke
# 68      M8Y         Etobicoke
# 69      M8Z         Etobicoke
# 70      M9B         Etobicoke
# 71      M9C         Etobicoke
# 72      M9L        North York
# 73      M9M        North York
# 74      M9N              York
# 75      M9R         Etobicoke
# 76      M9V         Etobicoke
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                      Rouge, Malvern  43.806686 -79.194353
# 1              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 2                              Morningside, West Hill  43.763573 -79.188711
# 3                                              Woburn  43.770992 -79.216917
# 4                                 Scarborough Village  43.744734 -79.239476
# 5                               Ionview, Kennedy Park  43.727929 -79.262029
# 6                     Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 7                               Cliffcrest, Cliffside  43.716316 -79.239476
# 8                                         Birch Cliff  43.692657 -79.264848
# 9   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 10                                  Maryvale, Wexford  43.750072 -79.295849
# 11                                          Agincourt  43.794200 -79.262029
# 12                                      Tam O'Shanter  43.781638 -79.304302
# 13                          Agincourt North, Milliken  43.815252 -79.284577
# 14                                        Upper Rouge  43.836125 -79.205636
# 15                                  Hillcrest Village  43.803762 -79.363452
# 16                                         Henry Farm  43.778517 -79.346556
# 17                                    Bayview Village  43.786947 -79.385975
# 18                                         York Mills  43.757490 -79.374714
# 19                            Newtonbrook, Willowdale  43.789053 -79.408493
# 20                                    Willowdale West  43.782736 -79.442259
# 21                                          Parkwoods  43.753259 -79.329656
# 22                                    Flemingdon Park  43.725900 -79.340923
# 23                     Bathurst Manor, Wilson Heights  43.754328 -79.442259
# 24                    Northwood Park, York University  43.767980 -79.487262
# 25                                        CFB Toronto  43.737473 -79.464763
# 26                                     Downsview West  43.739015 -79.506944
# 27                                   Victoria Village  43.725882 -79.315572
# 28                    Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 29                                   Woodbine Heights  43.695344 -79.318389
# ..                                                ...        ...        ...
# 47                                     Commerce Court  43.648198 -79.379817
# 48                                       Bedford Park  43.733283 -79.419750
# 49                                  Forest Hill North  43.696948 -79.411307
# 50                               The Annex, Yorkville  43.672710 -79.405678
# 51                              University of Toronto  43.662696 -79.400049
# 52          Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 53  CN Tower, King and Spadina, Railway Lands, Sou...  43.628947 -79.394420
# 54             First Canadian Place, Underground city  43.648429 -79.382280
# 55                   Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 56                                 Dovercourt Village  43.669005 -79.442259
# 57                           Little Portugal, Trinity  43.647927 -79.419750
# 58                 Exhibition Place, Parkdale Village  43.636847 -79.428191
# 59                                          Downsview  43.713756 -79.490074
# 60              Keelesdale, Mount Dennis, Silverthorn  43.691116 -79.476013
# 61                                          High Park  43.661608 -79.464763
# 62                             Parkdale, Roncesvalles  43.648960 -79.456325
# 63                                 Runnymede, Swansea  43.651571 -79.484450
# 64                                       Queen's Park  43.662301 -79.389494
# 65                                        New Toronto  43.605647 -79.501321
# 66                             Alderwood, Long Branch  43.602414 -79.543484
# 67                                       The Kingsway  43.653654 -79.506944
# 68  Humber Bay, Mimico NE, Old Mill South, The Que...  43.636258 -79.498509
# 69                      Mimico NW, The Queensway West  43.628841 -79.520999
# 70       Islington, Princess Gardens, West Deane Park  43.650943 -79.554724
# 71                                      Markland Wood  43.643515 -79.577201
# 72                                      Humber Summit  43.756303 -79.565963
# 73                                   Emery, Humberlea  43.724766 -79.532242
# 74                                             Weston  43.706876 -79.518188
# 75                                  Kingsview Village  43.688905 -79.554724
# 76  Beaumond Heights, Jamestown, Mount Olive, Silv...  43.739416 -79.588437
#
# [77 rows x 5 columns]

# %% [markdown]
# geographical coordinates of Manhattan

# %%
# !conda install -c conda-forge geopy --yes
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::numba==0.43.1=py37h6440ff4_0
#   - defaults/osx-64::anaconda==2019.03=py37_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/fabiomendes/anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.03  |           py37_0           5 KB
#     anaconda-custom            |           py37_1           3 KB
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     certifi-2019.11.28         |           py37_0         148 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     openssl-1.1.1d             |       h0b31af3_0         1.9 MB  conda-forge
#     tbb-2019.8                 |       h770b8ee_0         157 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2019.03-py37_0
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.20.0-py_0
#   tbb                conda-forge/osx-64::tbb-2019.8-h770b8ee_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2019.1.23-0 --> conda-forge::ca-certificates-2019.11.28-hecc5488_0
#   certifi                                   2019.3.9-py37_0 --> 2019.11.28-py37_0
#   openssl                                 1.1.1b-h1de35cc_1 --> 1.1.1d-h0b31af3_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2019.03-py37_0 --> custom-py37_1
#
#
#
# Downloading and Extracting Packages
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# tbb-2019.8           | 157 KB    | ##################################### | 100%
# certifi-2019.11.28   | 148 KB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# anaconda-custom      | 3 KB      | ##################################### | 100%
# _anaconda_depends-20 | 5 KB      | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.1.1d       | 1.9 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from geopy.geocoders import Nominatim

# %%
address = 'TORONTO, CANADA'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
import folium

# %%
# create map of Manhattan using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
